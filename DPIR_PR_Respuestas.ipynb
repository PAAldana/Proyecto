# %%
import pandas as pd
import numpy as np
import random
import datetime
import boto3
import botocore
import psycopg2
import configparser
from datetime import date

# %% [markdown]
# ### Nombre de la instancia

# %%
rdsIdentifier = 'dpir'

# %% [markdown]
# ### Cargar archivo de config.

# %%
config = configparser.ConfigParser()
config.read('config.cfg')
# Out:
# ['config.cfg']

# %% [markdown]
# ### Crear instancia

# %%
aws_data = boto3.client('rds', aws_access_key_id=config.get('IAM', 'ACCESS_KEY'),
                     aws_secret_access_key=config.get('IAM', 'SECRET_ACCESS_KEY'),
                     region_name='us-east-1')

# %% [markdown]
# ### Instancias disponibles

# %%
rdsInstanceIds = []

response = aws_data.describe_db_instances()
for resp in response['DBInstances']:
    rdsInstanceIds.append(resp['DBInstanceIdentifier'])
    db_instance_status = resp['DBInstanceStatus']

print(f"DBInstanceIds {rdsInstanceIds}")
# Out:
# DBInstanceIds ['dpir']

# %% [markdown]
# ### Creacion de servicio RDS

# %%
try:
    response = aws_data.create_db_instance(
            AllocatedStorage=10,
            DBName=config.get('RDS', 'DB_NAME'),
            DBInstanceIdentifier=rdsIdentifier,
            DBInstanceClass="db.t3.micro",
            Engine="postgres",
            MasterUsername=config.get('RDS', 'DB_USER'),
            MasterUserPassword=config.get('RDS', 'DB_PASSWORD'),
            Port=int(config.get('RDS', 'DB_PORT')),
            VpcSecurityGroupIds=["sg-02abf94b67ee35a24"],
            PubliclyAccessible=True
        )
    print (response)
except aws_data.exceptions.DBInstanceAlreadyExistsFault as ex:
    print("La Instancia de Base de Datos ya Existe.")
# Out:
# La Instancia de Base de Datos ya Existe.

# %% [markdown]
# ### Obteniendo URL del host

# %%
try:
     instances = aws_data.describe_db_instances(DBInstanceIdentifier=rdsIdentifier)
     RDS_HOST = instances.get('DBInstances')[0].get('Endpoint').get('Address')
     print(RDS_HOST)
except Exception as ex:
     print("La instancia de base de datos no existe o aun no se ha terminado de crear.")
     print(ex)
# Out:
# dpir.cfbnwxvpqafk.us-east-1.rds.amazonaws.com

# %%
postgres_driver = f"""postgresql://{config.get('RDS', 'DB_USER')}:{config.get('RDS', 'DB_PASSWORD')}@{RDS_HOST}:{config.get('RDS', 'DB_PORT')}/{config.get('RDS', 'DB_NAME')}"""

# %%
postgres_driver
# Out:
# 'postgresql://a_dpir:QaO0kD9pGC53@dpir.cfbnwxvpqafk.us-east-1.rds.amazonaws.com:5432/dpir'

# %% [markdown]
# ### Lectura fact_precio

# %%
sql_query = 'select * from fact_precio fp'
df_precios = pd.read_sql(sql_query, postgres_driver)
df_precios.head(5)
# Out:
#    Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Date_key  \
# 0          1          128           399          3          1     42152
# 1          2            5           382          3          1     42375
# 2          3            5           384          3          1     42375
# 3          4            5           413          3          1     42375
# 4          5            5           391          3          1     42375
#
#    Divisa_FK  Precio          Marca  Pais         NOG Responsable  \
# 0          8  350.00           None  None  24538745.0        None
# 1          8    9.10        ATRAMAT  None   4958969.0        None
# 2          8    6.00        B BRAUN  None   4958969.0        None
# 3          8    3.80  VITAL SUTURES  None   4958969.0        None
# 4          8   10.11          TAGUM  None   4958969.0        None
#
#   Observaciones            timestamp
# 0          None  2023-04-09 11:39:05
# 1          None  2023-04-09 11:39:05
# 2          None  2023-04-09 11:39:05
# 3          None  2023-04-09 11:39:05
# 4          None  2023-04-09 11:39:05

# %% [markdown]
# ### Limpieza Data

# %%
df_precios=df_precios.iloc[:,0:8]
df_precios
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Date_key  \
# 0             1          128           399          3          1     42152
# 1             2            5           382          3          1     42375
# 2             3            5           384          3          1     42375
# 3             4            5           413          3          1     42375
# 4             5            5           391          3          1     42375
# ...         ...          ...           ...        ...        ...       ...
# 1934       1935          127           465          5          1     44995
# 1935       1936          127           466          5          1     44995
# 1936       1937          129           467          5          1     44995
# 1937       1938          148           468          5          1     44995
# 1938       1939          148           469          5          1     44995
#
#       Divisa_FK  Precio
# 0             8  350.00
# 1             8    9.10
# 2             8    6.00
# 3             8    3.80
# 4             8   10.11
# ...         ...     ...
# 1934         10   12.31
# 1935         10   12.79
# 1936         10   12.31
# 1937          9    2.81
# 1938          9   53.96
#
# [1939 rows x 8 columns]

# %% [markdown]
# ### Lectura de Dim_divisas

# %%
sql_query = 'select * from "dim_divisas" '
df_divisa = pd.read_sql(sql_query, postgres_driver)
df_divisa
# Out:
#    Divisa_FK                Divisa Abreviatura Simbolo        timestamp
# 0          8  Quetzal Guatemalteco         GTQ       Q  5/04/2023 17:44
# 1          9  Dolar Estadounidense         USD       $  5/04/2023 17:44
# 2         10                  Euro         EUR     â¬  5/04/2023 17:44
# 3         11         Peso Mexicano         MXN       $  5/04/2023 17:44
# 4         12         Peso Filipino         PHP     â±  5/04/2023 17:44
# 5         13           Rupia India         INR     â¹  5/04/2023 17:44
# 6         14               Bolivar         VED      Bs  5/04/2023 17:44
# 7         15        Peso Argentino         ARP      $a  5/04/2023 17:44

# %% [markdown]
# ### Cargando Bucket de S3: 'Tipo de Cambio'

# %%
s3 = boto3.resource(
    service_name = 's3',
    region_name = 'us-east-1',
    aws_access_key_id = config.get('IAM', 'ACCESS_KEY'),
    aws_secret_access_key = config.get('IAM', 'SECRET_ACCESS_KEY')
)

# %%
for bucket in s3.buckets.all():
    S3_BUCKET_NAME = bucket.name
    print(bucket.name)
# Out:
# dpir2023

# %%
S3_BUCKET_NAME='dpir2023'

# %%
import io
remoteFileList = []
for objt in s3.Bucket(S3_BUCKET_NAME).objects.all():
    remoteFileList.append(objt.key)

remoteFileList
# Out:
# ['divisas/', 'divisas/Tipocambio.csv', 'ipc/', 'ipc/IPC.csv']

# %%
file = s3.Bucket(S3_BUCKET_NAME).Object('divisas/Tipocambio.csv').get()
data=io.BytesIO(file['Body'].read())
df_TdC=pd.read_csv(data,sep=';',encoding='latin1')
df_TdC
# Out:
#                  Divisa  Tipo de cambio
# 0  Quetzal Guatemalteco          1.0000
# 1  Dolar Estadounidense          7.7964
# 2                  Euro          8.5030
# 3         Peso Mexicano          0.4315
# 4         Peso Filipino          0.1400
# 5           Rupia India          0.0948
# 6               Bolivar          0.3191
# 7        Peso Argentino          0.0371

# %% [markdown]
# ### Join Tipo de cambio y divisa

# %%
df_divisa_TDC=df_divisa.merge(df_TdC,how='inner',on='Divisa')
df_divisa_TDC.drop(['Divisa','Abreviatura','Simbolo','timestamp'], axis=1,  inplace=True)
df_divisa_TDC
# Out:
#    Divisa_FK  Tipo de cambio
# 0          8          1.0000
# 1          9          7.7964
# 2         10          8.5030
# 3         11          0.4315
# 4         12          0.1400
# 5         13          0.0948
# 6         14          0.3191
# 7         15          0.0371

# %% [markdown]
# ### Join Tipo de cambio y Precios
# Realizamos el Join de la tabla de precios con el tipo de cambio para luego realizar la conversión de la moneda a moneda local (Q)

# %%
df_Precio_Div=df_precios.merge(df_divisa_TDC,how='inner',on='Divisa_FK')

df_Precio_Div.head()
# Out:
#    Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Date_key  \
# 0          1          128           399          3          1     42152
# 1          2            5           382          3          1     42375
# 2          3            5           384          3          1     42375
# 3          4            5           413          3          1     42375
# 4          5            5           391          3          1     42375
#
#    Divisa_FK  Precio  Tipo de cambio
# 0          8  350.00             1.0
# 1          8    9.10             1.0
# 2          8    6.00             1.0
# 3          8    3.80             1.0
# 4          8   10.11             1.0

# %%
df_Precio_Div['Precio_Q']=df_Precio_Div['Precio']*df_Precio_Div['Tipo de cambio']
df_Precio_Div
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Date_key  \
# 0             1          128           399          3          1     42152
# 1             2            5           382          3          1     42375
# 2             3            5           384          3          1     42375
# 3             4            5           413          3          1     42375
# 4             5            5           391          3          1     42375
# ...         ...          ...           ...        ...        ...       ...
# 1934       1891           95           452          5          1     44995
# 1935       1892           95           452          5          1     44995
# 1936       1895          115           452          5          1     44995
# 1937       1932           90           453          5          1     44995
# 1938       1933           92           453          5          1     44995
#
#       Divisa_FK  Precio  Tipo de cambio    Precio_Q
# 0             8  350.00          1.0000  350.000000
# 1             8    9.10          1.0000    9.100000
# 2             8    6.00          1.0000    6.000000
# 3             8    3.80          1.0000    3.800000
# 4             8   10.11          1.0000   10.110000
# ...         ...     ...             ...         ...
# 1934         14  168.58          0.3191   53.793878
# 1935         14  166.70          0.3191   53.193970
# 1936         14  492.92          0.3191  157.290772
# 1937         15  607.37          0.0371   22.533427
# 1938         15  607.37          0.0371   22.533427
#
# [1939 rows x 10 columns]

# %% [markdown]
# ### Limpiamos columnas sin uso.

# %%
df_precios=df_Precio_Div.drop(['Precio','Tipo de cambio','Divisa_FK'], axis=1)
df_precios
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Date_key  \
# 0             1          128           399          3          1     42152
# 1             2            5           382          3          1     42375
# 2             3            5           384          3          1     42375
# 3             4            5           413          3          1     42375
# 4             5            5           391          3          1     42375
# ...         ...          ...           ...        ...        ...       ...
# 1934       1891           95           452          5          1     44995
# 1935       1892           95           452          5          1     44995
# 1936       1895          115           452          5          1     44995
# 1937       1932           90           453          5          1     44995
# 1938       1933           92           453          5          1     44995
#
#         Precio_Q
# 0     350.000000
# 1       9.100000
# 2       6.000000
# 3       3.800000
# 4      10.110000
# ...          ...
# 1934   53.793878
# 1935   53.193970
# 1936  157.290772
# 1937   22.533427
# 1938   22.533427
#
# [1939 rows x 7 columns]

# %% [markdown]
# ### Cargando Bucket de S3: 'IPC'

# %%
file = s3.Bucket(S3_BUCKET_NAME).Object('ipc/IPC.csv').get()
data=io.BytesIO(file['Body'].read())
df_ipc=pd.read_csv(data,sep=';')
df_ipc.drop(df_ipc.iloc[:, 2:13],axis = 1,inplace=True)
df_ipc['Mes']=df_ipc['Mes'].str.lower()
df_ipc
# Out:
#       Año        Mes  Bienes y servicios diversos
# 0    2011      abril                       101.31
# 1    2011       mayo                       101.60
# 2    2011      junio                       101.73
# 3    2011      julio                       101.79
# 4    2011     agosto                       102.01
# ..    ...        ...                          ...
# 138  2022    octubre                       129.74
# 139  2022  noviembre                       130.02
# 140  2022  diciembre                       130.69
# 141  2023      enero                       131.06
# 142  2023    febrero                       131.51
#
# [143 rows x 3 columns]

# %%
ipc_Now=df_ipc['Bienes y servicios diversos'].iloc[-1]
ipc_Now
# Out:
# 131.51

# %% [markdown]
# ### Lectura Dim Date

# %%
sql_query = 'select * from dim_date fp'
df_date = pd.read_sql(sql_query, postgres_driver)
df_date.head(5)
# Out:
#    Date_key       Fecha    Mes   Año  Mes_Año  Fecha +40d
# 0     42005  2015-01-01  enero  2015   1.2015  2015-02-10
# 1     42006  2015-01-02  enero  2015   1.2015  2015-02-11
# 2     42007  2015-01-03  enero  2015   1.2015  2015-02-12
# 3     42008  2015-01-04  enero  2015   1.2015  2015-02-13
# 4     42009  2015-01-05  enero  2015   1.2015  2015-02-14

# %% [markdown]
# ### Añade Rúbrica de antiguedad

# %%
df_date['Pond_D']=0
df_date.loc[df_date['Año']>=2021,'Pond_D']=1
df_date.loc[df_date['Año']<2019,'Pond_D']=-1
df_date
# Out:
#       Date_key       Fecha        Mes   Año  Mes_Año  Fecha +40d  Pond_D
# 0        42005  2015-01-01      enero  2015   1.2015  2015-02-10      -1
# 1        42006  2015-01-02      enero  2015   1.2015  2015-02-11      -1
# 2        42007  2015-01-03      enero  2015   1.2015  2015-02-12      -1
# 3        42008  2015-01-04      enero  2015   1.2015  2015-02-13      -1
# 4        42009  2015-01-05      enero  2015   1.2015  2015-02-14      -1
# ...        ...         ...        ...   ...      ...         ...     ...
# 3282     45287  2023-12-27  diciembre  2023  12.2023  2024-02-05       1
# 3283     45288  2023-12-28  diciembre  2023  12.2023  2024-02-06       1
# 3284     45289  2023-12-29  diciembre  2023  12.2023  2024-02-07       1
# 3285     45290  2023-12-30  diciembre  2023  12.2023  2024-02-08       1
# 3286     45291  2023-12-31  diciembre  2023  12.2023  2024-02-09       1
#
# [3287 rows x 7 columns]

# %% [markdown]
# ### Join Precios con Dim Date

# %%
df_Precios_Date=df_precios.merge(df_date,how='inner', on='Date_key')
df_Precios_Date
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Date_key  \
# 0             1          128           399          3          1     42152
# 1             2            5           382          3          1     42375
# 2             3            5           384          3          1     42375
# 3             4            5           413          3          1     42375
# 4             5            5           391          3          1     42375
# ...         ...          ...           ...        ...        ...       ...
# 1934       1891           95           452          5          1     44995
# 1935       1892           95           452          5          1     44995
# 1936       1895          115           452          5          1     44995
# 1937       1932           90           453          5          1     44995
# 1938       1933           92           453          5          1     44995
#
#         Precio_Q       Fecha    Mes   Año  Mes_Año  Fecha +40d  Pond_D
# 0     350.000000  2015-05-28   mayo  2015   5.2015  2015-07-07      -1
# 1       9.100000  2016-01-06  enero  2016   1.2016  2016-02-15      -1
# 2       6.000000  2016-01-06  enero  2016   1.2016  2016-02-15      -1
# 3       3.800000  2016-01-06  enero  2016   1.2016  2016-02-15      -1
# 4      10.110000  2016-01-06  enero  2016   1.2016  2016-02-15      -1
# ...          ...         ...    ...   ...      ...         ...     ...
# 1934   53.793878  2023-03-10  marzo  2023   3.2023  2023-04-19       1
# 1935   53.193970  2023-03-10  marzo  2023   3.2023  2023-04-19       1
# 1936  157.290772  2023-03-10  marzo  2023   3.2023  2023-04-19       1
# 1937   22.533427  2023-03-10  marzo  2023   3.2023  2023-04-19       1
# 1938   22.533427  2023-03-10  marzo  2023   3.2023  2023-04-19       1
#
# [1939 rows x 13 columns]

# %%
df_Precios_Date.drop(['Date_key','Fecha','Mes_Año','Fecha +40d'],axis=1,inplace=True)
df_Precios_Date
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK    Precio_Q  \
# 0             1          128           399          3          1  350.000000
# 1             2            5           382          3          1    9.100000
# 2             3            5           384          3          1    6.000000
# 3             4            5           413          3          1    3.800000
# 4             5            5           391          3          1   10.110000
# ...         ...          ...           ...        ...        ...         ...
# 1934       1891           95           452          5          1   53.793878
# 1935       1892           95           452          5          1   53.193970
# 1936       1895          115           452          5          1  157.290772
# 1937       1932           90           453          5          1   22.533427
# 1938       1933           92           453          5          1   22.533427
#
#         Mes   Año  Pond_D
# 0      mayo  2015      -1
# 1     enero  2016      -1
# 2     enero  2016      -1
# 3     enero  2016      -1
# 4     enero  2016      -1
# ...     ...   ...     ...
# 1934  marzo  2023       1
# 1935  marzo  2023       1
# 1936  marzo  2023       1
# 1937  marzo  2023       1
# 1938  marzo  2023       1
#
# [1939 rows x 9 columns]

# %% [markdown]
# ### Join IPC y Precios

# %%
df_Precios_IPC=df_Precios_Date.merge(df_ipc,how='inner',on=['Mes','Año'])
df_Precios_IPC
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Precio_Q  \
# 0             1          128           399          3          1    350.00
# 1             2            5           382          3          1      9.10
# 2             3            5           384          3          1      6.00
# 3             4            5           413          3          1      3.80
# 4             5            5           391          3          1     10.11
# ...         ...          ...           ...        ...        ...       ...
# 1870       1497          154           428          3          3   1370.00
# 1871       1498          135           394          3          1      5.40
# 1872       1499          154           428          3          3   1370.00
# 1873       1500           85           383          3          1     38.00
# 1874       1501          154           428          3          3   1370.00
#
#             Mes   Año  Pond_D  Bienes y servicios diversos
# 0          mayo  2015      -1                       114.40
# 1         enero  2016      -1                       116.16
# 2         enero  2016      -1                       116.16
# 3         enero  2016      -1                       116.16
# 4         enero  2016      -1                       116.16
# ...         ...   ...     ...                          ...
# 1870  noviembre  2022       1                       130.02
# 1871  noviembre  2022       1                       130.02
# 1872  diciembre  2022       1                       130.69
# 1873  diciembre  2022       1                       130.69
# 1874      enero  2023       1                       131.06
#
# [1875 rows x 10 columns]

# %% [markdown]
# ### Operar indexación

# %%
df_Precios_IPC['fIndex']=ipc_Now/df_Precios_IPC['Bienes y servicios diversos']
df_Precios_IPC['PIndex']=df_Precios_IPC['Precio_Q']*df_Precios_IPC['fIndex']
df_Precios_IPC.drop('Bienes y servicios diversos',axis=1,inplace=True)
df_Precios_IPC
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Marlon Daniel\anaconda3\envs\CienciaDatos2022\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\Marlon Daniel\anaconda3\envs\CienciaDatos2022\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Marlon Daniel\anaconda3\envs\CienciaDatos2022\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bienes y servicios diversos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df_Precios_IPC['fIndex']=ipc_Now/df_Precios_IPC['Bienes y servicios diversos']
#       2 df_Precios_IPC['PIndex']=df_Precios_IPC['Precio_Q']*df_Precios_IPC['fIndex']
#       3 df_Precios_IPC.drop('Bienes y servicios diversos',axis=1,inplace=True)
#
# File c:\Users\Marlon Daniel\anaconda3\envs\CienciaDatos2022\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Marlon Daniel\anaconda3\envs\CienciaDatos2022\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Bienes y servicios diversos'

# %% [markdown]
# ### Reemplazar valores menores a 2 años por su valor indexado

# %%
df_Precios_IPC.loc[df_Precios_IPC['Año']<2021,'Precio_Q']=df_Precios_IPC['PIndex']
df_Precios_IPC
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK     Precio_Q  \
# 0             1          128           399          3          1   402.347028
# 1             2            5           382          3          1    10.302522
# 2             3            5           384          3          1     6.792872
# 3             4            5           413          3          1     4.302152
# 4             5            5           391          3          1    11.445989
# ...         ...          ...           ...        ...        ...          ...
# 1870       1497          154           428          3          3  1370.000000
# 1871       1498          135           394          3          1     5.400000
# 1872       1499          154           428          3          3  1370.000000
# 1873       1500           85           383          3          1    38.000000
# 1874       1501          154           428          3          3  1370.000000
#
#             Mes   Año  Pond_D    fIndex       PIndex
# 0          mayo  2015      -1  1.149563   402.347028
# 1         enero  2016      -1  1.132145    10.302522
# 2         enero  2016      -1  1.132145     6.792872
# 3         enero  2016      -1  1.132145     4.302152
# 4         enero  2016      -1  1.132145    11.445989
# ...         ...   ...     ...       ...          ...
# 1870  noviembre  2022       1  1.011460  1385.699892
# 1871  noviembre  2022       1  1.011460     5.461883
# 1872  diciembre  2022       1  1.006274  1378.595914
# 1873  diciembre  2022       1  1.006274    38.238427
# 1874      enero  2023       1  1.003434  1374.703952
#
# [1875 rows x 11 columns]

# %% [markdown]
# ### Limpieza de data

# %%
df_precios=df_Precios_IPC
df_precios.drop(['Mes','Año','fIndex','PIndex'], axis=1,inplace=True)
df_precios
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK     Precio_Q  \
# 0             1          128           399          3          1   402.347028
# 1             2            5           382          3          1    10.302522
# 2             3            5           384          3          1     6.792872
# 3             4            5           413          3          1     4.302152
# 4             5            5           391          3          1    11.445989
# ...         ...          ...           ...        ...        ...          ...
# 1870       1497          154           428          3          3  1370.000000
# 1871       1498          135           394          3          1     5.400000
# 1872       1499          154           428          3          3  1370.000000
# 1873       1500           85           383          3          1    38.000000
# 1874       1501          154           428          3          3  1370.000000
#
#       Pond_D
# 0         -1
# 1         -1
# 2         -1
# 3         -1
# 4         -1
# ...      ...
# 1870       1
# 1871       1
# 1872       1
# 1873       1
# 1874       1
#
# [1875 rows x 7 columns]

# %% [markdown]
# ### Lectura Dim Fuente

# %%
sql_query = 'select * from dim_fuente fp'
df_fuente = pd.read_sql(sql_query, postgres_driver)
df_fuente
# Out:
#    Fuente_FK      FuenteDatos            timestamp
# 0          1     Cotizaciones  2023-04-06 01:26:56
# 1          2       Ofertas CA  2023-04-06 01:26:56
# 2          3     Guatecompras  2023-04-06 01:26:56
# 3          4    PR anteriores  2023-04-06 01:26:56
# 4          5  Internacionales  2023-04-06 01:26:56
# 5          6              FEL  2023-04-06 01:26:56

# %% [markdown]
# ### Se añade rúbrica de Fuente de dato

# %%
df_fuente['Pond_F']=[1,0,0,0,-1,2]
df_fuente
# Out:
#    Fuente_FK      FuenteDatos            timestamp  Pond_F
# 0          1     Cotizaciones  2023-04-06 01:26:56       1
# 1          2       Ofertas CA  2023-04-06 01:26:56       0
# 2          3     Guatecompras  2023-04-06 01:26:56       0
# 3          4    PR anteriores  2023-04-06 01:26:56       0
# 4          5  Internacionales  2023-04-06 01:26:56      -1
# 5          6              FEL  2023-04-06 01:26:56       2

# %% [markdown]
# ### Join Fuente con Precio

# %%
df_Precios_Fuente=df_precios.merge(df_fuente,how="inner",on='Fuente_FK')
df_Precios_Fuente
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK     Precio_Q  \
# 0             1          128           399          3          1   402.347028
# 1             2            5           382          3          1    10.302522
# 2             3            5           384          3          1     6.792872
# 3             4            5           413          3          1     4.302152
# 4             5            5           391          3          1    11.445989
# ...         ...          ...           ...        ...        ...          ...
# 1870       1419          154           428          2          3  1370.000000
# 1871       1420          156           414          2          1   109.500000
# 1872       1487          154           428          2          3  1370.000000
# 1873       1488          154           414          2          3  1492.000000
# 1874       1489          156           414          2          1   109.500000
#
#       Pond_D   FuenteDatos            timestamp  Pond_F
# 0         -1  Guatecompras  2023-04-06 01:26:56       0
# 1         -1  Guatecompras  2023-04-06 01:26:56       0
# 2         -1  Guatecompras  2023-04-06 01:26:56       0
# 3         -1  Guatecompras  2023-04-06 01:26:56       0
# 4         -1  Guatecompras  2023-04-06 01:26:56       0
# ...      ...           ...                  ...     ...
# 1870       1    Ofertas CA  2023-04-06 01:26:56       0
# 1871       1    Ofertas CA  2023-04-06 01:26:56       0
# 1872       1    Ofertas CA  2023-04-06 01:26:56       0
# 1873       1    Ofertas CA  2023-04-06 01:26:56       0
# 1874       1    Ofertas CA  2023-04-06 01:26:56       0
#
# [1875 rows x 10 columns]

# %% [markdown]
# ### Limpieza de Data
# Dado que en este ejemplo no trabajaremos con la unidad de "Medida" se eliminará de este análisis. Sin embargo se contempló en el DW ya que pueden existir casos donde la unidad de medida si sea tomada en cuenta

# %%
df_precios=df_Precios_Fuente.drop(['timestamp','Fuente_FK','Medida_FK'],axis=1)
df_precios
# Out:
#       Precio_ID  Producto_FK  Proveedor_FK     Precio_Q  Pond_D   FuenteDatos  \
# 0             1          128           399   402.347028      -1  Guatecompras
# 1             2            5           382    10.302522      -1  Guatecompras
# 2             3            5           384     6.792872      -1  Guatecompras
# 3             4            5           413     4.302152      -1  Guatecompras
# 4             5            5           391    11.445989      -1  Guatecompras
# ...         ...          ...           ...          ...     ...           ...
# 1870       1419          154           428  1370.000000       1    Ofertas CA
# 1871       1420          156           414   109.500000       1    Ofertas CA
# 1872       1487          154           428  1370.000000       1    Ofertas CA
# 1873       1488          154           414  1492.000000       1    Ofertas CA
# 1874       1489          156           414   109.500000       1    Ofertas CA
#
#       Pond_F
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 1870       0
# 1871       0
# 1872       0
# 1873       0
# 1874       0
#
# [1875 rows x 7 columns]

# %% [markdown]
# ### Agrupamos Precios por Producto y Proveedor, tomando Promedios de Precios y Ponderadores

# %%
df_precios.drop('Precio_ID',axis=1,inplace=True)

# %%
df_G_Precios=df_precios.groupby(['Producto_FK','Proveedor_FK','FuenteDatos'],as_index=False).mean()
df_G_Precios
# Out:
#      Producto_FK  Proveedor_FK      FuenteDatos     Precio_Q  Pond_D  Pond_F
# 0              1           383     Cotizaciones    22.000000     1.0     1.0
# 1              1           391     Cotizaciones    13.850000     1.0     1.0
# 2              1           394     Cotizaciones     6.400000     1.0     1.0
# 3              1           410     Cotizaciones    15.000000     1.0     1.0
# 4              2           382     Guatecompras    12.132605    -1.0     0.0
# ..           ...           ...              ...          ...     ...     ...
# 582          158           425       Ofertas CA  1230.730593     0.0     0.0
# 583          158           428     Guatecompras  1154.549933    -1.0     0.0
# 584          158           477  Internacionales   554.055480     1.0    -1.0
# 585          158           478  Internacionales   677.604070     1.0    -1.0
# 586          158           479  Internacionales   504.227900     1.0    -1.0
#
# [587 rows x 6 columns]

# %% [markdown]
# ### Rúbrica de Cantidad y Desviación

# %%
P_qty=[-3,-1,0,1,2,3]
P_CV=[-2,-1,0,1]

# %% [markdown]
# ### Creacion de experimentos estadísticos

# %%
import itertools

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return itertools.chain.from_iterable(itertools.combinations(s, r) for r in range(len(s)+1))

# %%
FD=df_fuente['FuenteDatos']
FD.drop([5],inplace=True)

# %%
ConjMuestral=pd.Series(powerset(FD))
ConjMuestral.drop([0],inplace=True)
ConjMuestral
# Out:
# 1                                       (Cotizaciones,)
# 2                                         (Ofertas CA,)
# 3                                       (Guatecompras,)
# 4                                      (PR anteriores,)
# 5                                    (Internacionales,)
# 6                            (Cotizaciones, Ofertas CA)
# 7                          (Cotizaciones, Guatecompras)
# 8                         (Cotizaciones, PR anteriores)
# 9                       (Cotizaciones, Internacionales)
# 10                           (Ofertas CA, Guatecompras)
# 11                          (Ofertas CA, PR anteriores)
# 12                        (Ofertas CA, Internacionales)
# 13                        (Guatecompras, PR anteriores)
# 14                      (Guatecompras, Internacionales)
# 15                     (PR anteriores, Internacionales)
# 16             (Cotizaciones, Ofertas CA, Guatecompras)
# 17            (Cotizaciones, Ofertas CA, PR anteriores)
# 18          (Cotizaciones, Ofertas CA, Internacionales)
# 19          (Cotizaciones, Guatecompras, PR anteriores)
# 20        (Cotizaciones, Guatecompras, Internacionales)
# 21       (Cotizaciones, PR anteriores, Internacionales)
# 22            (Ofertas CA, Guatecompras, PR anteriores)
# 23          (Ofertas CA, Guatecompras, Internacionales)
# 24         (Ofertas CA, PR anteriores, Internacionales)
# 25       (Guatecompras, PR anteriores, Internacionales)
# 26    (Cotizaciones, Ofertas CA, Guatecompras, PR an...
# 27    (Cotizaciones, Ofertas CA, Guatecompras, Inter...
# 28    (Cotizaciones, Ofertas CA, PR anteriores, Inte...
# 29    (Cotizaciones, Guatecompras, PR anteriores, In...
# 30    (Ofertas CA, Guatecompras, PR anteriores, Inte...
# 31    (Cotizaciones, Ofertas CA, Guatecompras, PR an...
# dtype: object

# %% [markdown]
# ### Cargando CATALOGO

# %%
sql_query = 'select * from fact_catalogo fp'
df_CAT = pd.read_sql(sql_query, postgres_driver)
df_CAT['Ponderacion']=-10
global df_CAT

# %% [markdown]
# ### Funcion de calculo de precios

# %%
def Ponderar(Elemento):
    global PR_i
    Filter_df=df_G_Precios.loc[df_G_Precios['FuenteDatos'].isin(Elemento)]
    E_df=Filter_df.groupby('Producto_FK').agg({'Precio_Q':['mean','std',lambda x: np.std(x)/np.mean(x)],'Pond_D':['mean'],'Pond_F':['mean'],'Proveedor_FK':['count']})
    E_df['Pond_Q']=0
    E_df['Pond_CV']=0
    # POND QTY
    E_df.loc[E_df['Proveedor_FK']['count']>10,'Pond_Q']=3
    E_df.loc[E_df['Proveedor_FK']['count'].isin([9,10]),'Pond_Q']=2
    E_df.loc[E_df['Proveedor_FK']['count'].isin([7,8]),'Pond_Q']=1
    E_df.loc[E_df['Proveedor_FK']['count'].isin([5,6]),'Pond_Q']=0
    E_df.loc[E_df['Proveedor_FK']['count'].isin([3,4]),'Pond_Q']=-1
    E_df.loc[E_df['Proveedor_FK']['count']<3,'Pond_Q']=-3
    #POND CV
    E_df.loc[E_df['Precio_Q']['<lambda_0>']<0.2,'Pond_CV']=+1
    E_df.loc[E_df['Precio_Q']['<lambda_0>']>=0.5,'Pond_CV']=-1
    E_df.loc[E_df['Precio_Q']['<lambda_0>']>=1,'Pond_CV']=-2
    #POND TOTAL
    E_df['POND']=E_df['Pond_CV']+E_df['Pond_Q']+E_df['Pond_D']['mean']+E_df['Pond_F']['mean']
    PR_i=pd.DataFrame([])
    PR_i['PRi']=E_df['Precio_Q']['mean']
    PR_i['POND']=E_df['POND']
    return PR_i

# %%
today = date.today()

# %%
for Elm in ConjMuestral:
    Ponderar(Elm)
    if len(PR_i)!= 0:
        CAT_compare=df_CAT.merge(PR_i,how='left',on='Producto_FK')
        CAT_compare.loc[CAT_compare['POND']>CAT_compare['Ponderacion'],'PR']=CAT_compare['PRi']
        CAT_compare.loc[CAT_compare['POND']>CAT_compare['Ponderacion'],'Date_key']=int(today.strftime('%Y%m%d'))
        CAT_compare.loc[CAT_compare['POND']>CAT_compare['Ponderacion'],'Observaciones']=str(Elm)
        CAT_compare.loc[CAT_compare['POND']>CAT_compare['Ponderacion'],'Ponderacion']=CAT_compare['POND']
        df_CAT=CAT_compare.drop(['PRi','POND'],axis=1)

# %% [markdown]
# ### Data Frame Resultado

# %%
df_CAT
# Out:
#      Catalogo_ID  Revision  Evento_FK  Renglon  Producto_FK  Medida_FK  \
# 0              1         1          2        1          154          3
# 1              2         1          2        2          155          2
# 2              3         1          2        3          156          1
# 3              4         1          2        4          157          1
# 4              5         1          2        5          158          2
# ..           ...       ...        ...      ...          ...        ...
# 153          154         1          1      149          149          1
# 154          155         1          1      150          150          1
# 155          156         1          1      151          151          1
# 156          157         1          1      152          152          1
# 157          158         1          1      153          153          1
#
#      Cantidad  Rubro_FK            timestamp           PR  Date_key  \
# 0        7700        13  2023-04-06 12:47:32  1179.420000  20230409
# 1        3850        13  2023-04-06 12:47:32   228.728888  20230409
# 2        3300        13  2023-04-06 12:47:32   202.513079  20230409
# 3      367126        13  2023-04-06 12:47:32    64.762600  20230409
# 4        4554        13  2023-04-06 12:47:32   578.629150  20230409
# ..        ...       ...                  ...          ...       ...
# 153         5        11  2023-04-06 12:47:32   250.000000  20230409
# 154         1        11  2023-04-06 12:47:32   250.000000  20230409
# 155       120        11  2023-04-06 12:47:32   250.000000  20230409
# 156       120        11  2023-04-06 12:47:32   250.000000  20230409
# 157       120        11  2023-04-06 12:47:32   200.015000  20230409
#
#                                          Observaciones  Ponderacion
# 0       ('Cotizaciones', 'Ofertas CA', 'Guatecompras')     1.400000
# 1                  ('Guatecompras', 'Internacionales')    -0.666667
# 2    ('Cotizaciones', 'Ofertas CA', 'Internacionales')    -0.166667
# 3    ('Cotizaciones', 'Ofertas CA', 'Guatecompras',...     1.281250
# 4                                 ('Internacionales',)     0.000000
# ..                                                 ...          ...
# 153                                  ('Cotizaciones',)     0.000000
# 154                                  ('Cotizaciones',)     0.000000
# 155                                  ('Cotizaciones',)     0.000000
# 156                                  ('Cotizaciones',)     0.000000
# 157                                  ('Cotizaciones',)    -1.000000
#
# [158 rows x 13 columns]

# %% [markdown]
# ### Subir Información a PostgreSQL

# %%
def insertDataToSQL(data_dict, table_name):
     postgres_driver = f"""postgresql://{config.get('RDS', 'DB_USER')}:{config.get('RDS', 'DB_PASSWORD')}@{RDS_HOST}:{config.get('RDS', 'DB_PORT')}/{config.get('RDS', 'DB_NAME')}"""    
     df_data = pd.DataFrame.from_records(data_dict)
     try:
          response = df_data.to_sql(table_name, postgres_driver, index=False, if_exists='replace')
          print(f'Se han insertado {response} nuevos registros en {table_name}.' )
     except Exception as ex:
          print(ex)

# %%
export_CAT=df_CAT.drop('Ponderacion',axis=1)

insertDataToSQL(export_CAT,'fact_catalogo')
# Out:
# Se han insertado 158 nuevos registros en fact_catalogo.

# %% [markdown]
# ### Confirmar la subida correcta de Información:

# %%
sql_query = 'select * from fact_catalogo fp'
df_CAT = pd.read_sql(sql_query, postgres_driver)
df_CAT
# Out:
#      Catalogo_ID  Revision  Evento_FK  Renglon  Producto_FK  Medida_FK  \
# 0              1         1          2        1          154          3
# 1              2         1          2        2          155          2
# 2              3         1          2        3          156          1
# 3              4         1          2        4          157          1
# 4              5         1          2        5          158          2
# ..           ...       ...        ...      ...          ...        ...
# 153          154         1          1      149          149          1
# 154          155         1          1      150          150          1
# 155          156         1          1      151          151          1
# 156          157         1          1      152          152          1
# 157          158         1          1      153          153          1
#
#      Cantidad  Rubro_FK            timestamp           PR  Date_key  \
# 0        7700        13  2023-04-06 12:47:32  1179.420000  20230409
# 1        3850        13  2023-04-06 12:47:32   228.728888  20230409
# 2        3300        13  2023-04-06 12:47:32   202.513079  20230409
# 3      367126        13  2023-04-06 12:47:32    64.762600  20230409
# 4        4554        13  2023-04-06 12:47:32   578.629150  20230409
# ..        ...       ...                  ...          ...       ...
# 153         5        11  2023-04-06 12:47:32   250.000000  20230409
# 154         1        11  2023-04-06 12:47:32   250.000000  20230409
# 155       120        11  2023-04-06 12:47:32   250.000000  20230409
# 156       120        11  2023-04-06 12:47:32   250.000000  20230409
# 157       120        11  2023-04-06 12:47:32   200.015000  20230409
#
#                                          Observaciones
# 0       ('Cotizaciones', 'Ofertas CA', 'Guatecompras')
# 1                  ('Guatecompras', 'Internacionales')
# 2    ('Cotizaciones', 'Ofertas CA', 'Internacionales')
# 3    ('Cotizaciones', 'Ofertas CA', 'Guatecompras',...
# 4                                 ('Internacionales',)
# ..                                                 ...
# 153                                  ('Cotizaciones',)
# 154                                  ('Cotizaciones',)
# 155                                  ('Cotizaciones',)
# 156                                  ('Cotizaciones',)
# 157                                  ('Cotizaciones',)
#
# [158 rows x 12 columns]

# %% [markdown]
# ## __Analitica__

# %% [markdown]
# ### 1.¿Cuál es el precio más indexado al día de hoy?

# %%
df_precios.head(2)
# Out:
#    Producto_FK  Proveedor_FK    Precio_Q  Pond_D   FuenteDatos  Pond_F
# 0          128           399  402.347028      -1  Guatecompras       0
# 1            5           382   10.302522      -1  Guatecompras       0

# %%
sql_query = 'select * from "dim_productos" '
df_producto = df_producto = pd.read_sql(sql_query, postgres_driver)
df_producto.head(2)
# Out:
#    Producto_FK      Cod_INE  \
# 0            1  295-491-000
# 1            2  295-492-000
#
#                                               Nombre  \
# 0  SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...
# 1  SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...
#
#                                     Especificaciones            timestamp
# 0  SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...  2023-04-06 01:28:12
# 1  SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...  2023-04-06 01:28:12

# %%
mayor_indexacion = df_producto[df_producto['Producto_FK']== 128]
mayor_indexacion
# Out:
#      Producto_FK      Cod_INE  \
# 127          128  295-618-000
#
#                                                 Nombre  \
# 127  SUTURA NO ABSORBIBLE SINTÉTICA, MONOFILAMENTO,...
#
#                                       Especificaciones            timestamp
# 127  SUTURA NO ABSORBIBLE SINTÉTICA, MONOFILAMENTO,...  2023-04-06 01:28:12

# %% [markdown]
# ### EL producto con mayor precio indexado al hoy es la SUTURA NO ABSORBIBLE SINTÉTICA, MONOFILAMENTO con condigo INE 295-618-000 y precio de Q 402.347028

# %% [markdown]
# ### 2. Cuál es el precio de la cantidad de productos con mayor adquisición?

# %% [markdown]
# ### Cual es el precio de la cantidad mas grande adquirida

# %%
cant_precio = df_CAT[['Cantidad','PR']]
cant_precio.sort_values(by='Cantidad', ascending=False).head(3)
# Out:
#    Cantidad          PR
# 3    367126    64.76260
# 0      7700  1179.42000
# 4      4554   578.62915

# %%
print("El precio de la cantidad mas grande adquirida es 64.76260")
# Out:
# El precio de la cantidad mas grande adquirida es 64.76260

# %% [markdown]
# ### 3.¿Qué productos tienen dos (2) o menos años de antigüedad?

# %%
df_date.head(4)
# Out:
#    Date_key       Fecha    Mes   Año  Mes_Año  Fecha +40d  Pond_D
# 0     42005  2015-01-01  enero  2015   1.2015  2015-02-10      -1
# 1     42006  2015-01-02  enero  2015   1.2015  2015-02-11      -1
# 2     42007  2015-01-03  enero  2015   1.2015  2015-02-12      -1
# 3     42008  2015-01-04  enero  2015   1.2015  2015-02-13      -1

# %%
antiguedad_menor_a_dos_años = df_Precios_Date[df_Precios_Date['Año']>2021]
antiguedad_menor_a_dos_años = antiguedad_menor_a_dos_años.drop_duplicates(subset=['Producto_FK'])
cantidad= print(antiguedad_menor_a_dos_años.shape)
print(f"se tienen 155 productos diferentes con menos de dos años de antiguedad")
# Out:
# (155, 9)
# se tienen 155 productos diferentes con menos de dos años de antiguedad

# %%
antiguedad_menor_a_dos_años.head(5)
# Out:
#      Precio_ID  Producto_FK  Proveedor_FK  Fuente_FK  Medida_FK  Precio_Q  \
# 279       1562           73           383          1          1      60.0
# 280       1563           79           383          1          1      40.0
# 281       1564           80           383          1          1      40.0
# 282       1517            7           379          1          1      24.1
# 283       1518            8           379          1          1      24.1
#
#          Mes   Año  Pond_D
# 279  febrero  2023       1
# 280  febrero  2023       1
# 281  febrero  2023       1
# 282  febrero  2023       1
# 283  febrero  2023       1

# %%
producto1 = df_producto[df_producto['Producto_FK']==73]

# %%
producto2 =df_producto[df_producto['Producto_FK']==79]

# %%
producto3 = df_producto[df_producto['Producto_FK']==80]

# %%
producto4 = df_producto[df_producto['Producto_FK']==7]

# %%
producto5 = df_producto[df_producto['Producto_FK']==8]

# %%
top5 = pd.concat([producto1,producto2,producto3,producto4,producto5])
top5
# Out:
#     Producto_FK      Cod_INE  \
# 72           73  295-563-000
# 79           79  295-569-000
# 80           80  295-570-000
# 6             7  295-497-000
# 7             8  295-498-000
#
#                                                Nombre  \
# 72  SUTURA ABSORBIBLE SINTÉTICA, MONOFILAMENTO, CO...
# 79  SUTURA ABSORBIBLE SINTÉTICA, MONOFILAMENTO, CO...
# 80  SUTURA ABSORBIBLE SINTÉTICA, MONOFILAMENTO, CO...
# 6   SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...
# 7   SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...
#
#                                      Especificaciones            timestamp
# 72  SUTURA ABSORBIBLE SINTÉTICA, DE POLIGLECAPRONA...  2023-04-06 01:28:12
# 79  SUTURA ABSORBIBLE SINTÉTICA, DE POLIGLECAPRONA...  2023-04-06 01:28:12
# 80  SUTURA ABSORBIBLE SINTÉTICA, DE POLIGLECAPRONA...  2023-04-06 01:28:12
# 6   SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...  2023-04-06 01:28:12
# 7   SUTURA ABSORBIBLE NATURAL CRÓMICA (CATGUT CRÓM...  2023-04-06 01:28:12

# %% [markdown]
# ### Se tienen 155 productos diferentes con menos de 2 años y arriba se muestra el top 5 de los productos mas nuevos

# %% [markdown]
# ### 4. ¿Qué precios tienen un CV mayor o igual a 0.50?

# %%
df_precios.head(3)
# Out:
#    Producto_FK  Proveedor_FK    Precio_Q  Pond_D   FuenteDatos  Pond_F
# 0          128           399  402.347028      -1  Guatecompras       0
# 1            5           382   10.302522      -1  Guatecompras       0
# 2            5           384    6.792872      -1  Guatecompras       0

# %%
cv = (df_precios['Precio_Q'] - np.mean(df_precios['Precio_Q'])) / np.mean(df_precios['Precio_Q'])
cv = cv[cv >=0.50]
print(f"se tienen {len(cv)} precios con un coeficiente de variacion mayor o igual a 0.50 \n")
print("Se muestran los primeros 5: ")
cv.head()
# Out:
# se tienen 136 precios con un coeficiente de variacion mayor o igual a 0.50
#
# Se muestran los primeros 5:
# 0       6.379798
# 56     20.305508
# 110    20.219900
# 300     2.955335
# 304     3.921011
# Name: Precio_Q, dtype: float64

# %% [markdown]
# ### 5. ¿Cuál es el precio de referencia con mejor ponderación?

# %%
ponderacion = df_precios.sort_values('Pond_F', ascending=False)
mejor_ponderacion = ponderacion[ponderacion['Pond_F']>=1]
mejor_ponderacion = mejor_ponderacion.drop_duplicates(subset=['Producto_FK'])
mejor_ponderacion.shape
print(f"Se tienen 132 productos diferentes con la mejor ponderacion \nse muestran acontinuacion: \n")
mejor_ponderacion.head(5)
# Out:
# Se tienen 132 productos diferentes con la mejor ponderacion
# se muestran acontinuacion:
#       Producto_FK  Proveedor_FK  Precio_Q  Pond_D   FuenteDatos  Pond_F
# 1541           81           383     40.00       1  Cotizaciones       1
# 1620           29           391     11.31       1  Cotizaciones       1
# 1610           19           391     11.31       1  Cotizaciones       1
# 1611           20           391     11.31       1  Cotizaciones       1
# 1612           21           391     11.31       1  Cotizaciones       1
